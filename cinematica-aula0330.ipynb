# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrieloliveira36750-tech/cnweb_2b2_a/blob/main/cinematica-aula0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fórmula da velocidade
# fonte: [https://www.todamateria.com.br/formulas-de-cinematica/]

# %%
def calculaVelMedia(deltaS, deltaT):
  velMedia = (deltaS/deltaT)
  return velMedia

# %% [markdown]
# ## Teste Serviço Nuvem: Velocidade Média

# %%
print("Vm=", calculaVelMedia(30, 15))
# Out:
# Vm= 2.0

# %% [markdown]
# # Fórmula da aceleração

# %%
def calculaAceMedia(veloF, veloI, temF, temI ):
  aMedia = (veloF - veloI/temF - temI)
  return aMedia

# %% [markdown]
# ## Teste Serviço Nuvem: Aceleração Média

# %%
print("Am=", calculaAceMedia(4, 2, 8, 12))
# Out:
# Am= -8.25

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %%
def calculaMU(S, So, v, t):
  S = (So + v*t)
  return S

# %% [markdown]
# ## Teste Serviço Nuvem: Movimento Uniforme

# %%
print("S=", calculaMU(4, 2, 8, 18))
# Out:
# S= 146

# %% [markdown]
# # Função horária do deslocamento

# %%
def calculaDES(S, So, v, deltat):
  S = (So + v*deltat)
  return S

# %%
print("Deslocamento=", calculaDES(3, 5, 9, 19))
# Out:
# Deslocamento= 176

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %%
def calculaMUV(V, Vo, a, t):
  V = (Vo + a*t)
  return V

# %% [markdown]
# ## Teste Serviço Nuvem: Movimento Uniforme Variado

# %%
print("V=", calculaMUV(4, 2, 8, 18))
# Out:
# V= 146

# %% [markdown]
# ## Função horária da velocidade

# %%
def calculaFVEl(V, Vo, a, deltat):
  V = (Vo + a*deltat)
  return V

# %% [markdown]
# ## Teste Serviço Nuvem: Função Horária da Velocidade

# %%
print("FunçãoVelocidade=", calculaFVEl(4, 2, 8, 18))
# Out:
# FunçãoVelocidade= 146

# %% [markdown]
# ## Função horária da posição

# %%
import math

def calculaFPoS(so, vo, a, t):
  st = so+vo*t + 0.5*a*t**2
  return st

# %% [markdown]
# ## Teste Serviço Nuvem: Função Horária da Posição

# %%
print("Fp=", calculaFPoS(4,2,4,5))
# Out:
# Fp= 64.0

# %% [markdown]
# # Equação de Torricelli

# %%
  import math

  def calcTorricelli(vZero, acel, des):
    t= 2*acel*des
    v=vZero+t
    res = round(math.sqrt(v), 2)
    return res

# %% [markdown]
# ## Teste Serviço Nuvem: Função Torricelli

# %%
print("Calculo de Torricelli: ",calcTorricelli(0, 1, 8))
# Out:
# Calculo de Torricelli:  4.0

# %% [markdown]
# # Fórmula do movimento vertical

# %%
import math

def calcMV(vo, g, h):
v=vo**2 +- 2*g*h
return v
# Out:
#   File "/tmp/ipykernel_14650/563578441.py", line 4
#     v=vo**2 +- 2*g*h
#     ^
# IndentationError: expected an indented block after function definition on line 3
